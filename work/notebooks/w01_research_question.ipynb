# %% [markdown]
# <a href="https://colab.research.google.com/github/shah833/Flyrank-ML-Internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/shah833/Flyrank-ML-Internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ### I'm choosing the lane Refresh/Content Opportunity Scoring because I already have a head start on it from Notebook 1, where I saw a hand-written rule catch only 12 of the top 50 declining pages, while a trained model caught 37 of 50 which is nearly 3x better. This showed me there's a real, learnable pattern in the data that a simple rule misses, which makes this lane worth pursuing further

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ### **Decision:** Which pages are declining and should be prioritized for review first?
#
# ### **Who acts on it:** An SEO reviewer picks the top N pages from the ranked queue and assigns them to a content editor/writer to refresh.
#
# ### **Cost of a wrong call:** If a page that's actually fine gets ranked too high, it wastes editor/writer time on unnecessary work. If a page that's genuinely declining gets ranked too low, it gets missed and continues losing traffic — a real cost to the business.
#
# ### **Why ML, not just a rule:** A hand-written rule only correctly identified about 12 of the top 50 declining pages, while a trained model identified about 37 of 50 — nearly 3x better. This shows a simple rule misses too many real patterns in the data, and a learned model captures signal a fixed rule can't.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os, sys, subprocess

if not os.path.isdir("Flyrank-ML-Internship-task-1"):
    subprocess.run(["git", "clone", "--depth", "1", "https://github.com/shah833/Flyrank-ML-Internship-task-1"])

os.chdir("Flyrank-ML-Internship-task-1")
subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"])
subprocess.run([sys.executable, "scripts/run_all.py"])
# Out:
# CompletedProcess(args=['/usr/bin/python3', 'scripts/run_all.py'], returncode=0)

# %%
import json
res = json.load(open("outputs/model_results.json"))

base = res["baseline"]["baseline_precision_at_50"]
rf = res["models"]["random_forest"]["precision_at_50"]

print("Baseline rule Precision@50:", base)
print("Random forest Precision@50:", rf)
print("The model is roughly", round(rf/base, 1), "times better than the rule.")
# Out:
# Baseline rule Precision@50: 0.24
# Random forest Precision@50: 0.74
# The model is roughly 3.1 times better than the rule.

# %% [markdown]
# ### The random forest model correctly identifies about 3x more truly declining pages than a hand-written rule (Precision@50), showing this lane has a real, learnable pattern worth pursuing

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ### Based on the data, a trained model does a better job than a simple rule at spotting pages that need review (Precision@50: ~0.74 vs ~0.24). This can help an editor decide which pages to check first. It cannot prove why pages decline, cannot predict how Google's algorithm works, and cannot say that refreshing a page will cause it to improve — that would need a real experiment, not this analysis.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
